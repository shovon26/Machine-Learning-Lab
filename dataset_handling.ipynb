# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Getting the Dataset

# %%
dataset = pd.read_csv('/home/shovon26/Desktop/ML_Lab/stores.csv')

# %%
dataset.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46         0               1       4             4
# 1          17.02         0               1       4             4
# 2          18.61         1               1       4             1
# 3          19.44         1               0       3             1
# 4          17.02         0               0       3             2

# %%
dataset.tail()
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 27    STR128   Super Market  Super Market  Kolkata           30.4         40
# 28    STR129  Central Store  Super Market  Kolkata           15.8         80
# 29    STR130   Apparel Zone       Apparel  Kolkata           19.7         60
# 30    STR131  Fashion Bazar       Apparel  Kolkata           15.0         80
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 27        95.1              113            3.77       1.513           16.9
# 28       351.0              264            4.22       3.170           14.5
# 29       145.0              175            3.62       2.770           15.5
# 30       301.0              335            3.54       3.570           14.6
# 31       121.0              109            4.11       2.780           18.6
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 27         1               1       5             2
# 28         0               1       5             4
# 29         0               1       5             4
# 30         0               1       5             4
# 31         1               1       4             2

# %% [markdown]
# # Encoding categorial Data

# %%
x = dataset.iloc[:,:-1].values

# %%
x
# Out:
# array([['STR101', 'Electronics Zone', 'Electronincs', 'Delhi', 21.0, 60,
#         160.0, 110, 3.9, 2.62, 16.46, 0, 1, 4],
#        ['STR102', 'Apparel Zone', 'Apparel', 'Delhi', 21.0, 60, 160.0,
#         110, 3.9, 2.875, 17.02, 0, 1, 4],
#        ['STR103', 'Super Bazar', 'Super Market', 'Delhi', 22.8, 40,
#         108.0, 93, 3.85, 2.32, 18.61, 1, 1, 4],
#        ['STR104', 'Super Market', 'Super Market', 'Delhi', 21.4, 60,
#         258.0, 110, 3.08, 3.215, 19.44, 1, 0, 3],
#        ['STR105', 'Central Store', 'Super Market', 'Delhi', 18.7, 80,
#         360.0, 175, 3.15, 3.44, 17.02, 0, 0, 3],
#        ['STR106', 'Apparel Zone', 'Apparel', 'Delhi', 18.1, 60, 225.0,
#         105, 2.76, 3.46, 20.22, 1, 0, 3],
#        ['STR107', 'Fashion Bazar', 'Apparel', 'Delhi', 14.3, 80, 360.0,
#         245, 3.21, 3.57, 15.84, 0, 0, 3],
#        ['STR108', 'Digital Bazar', 'Electronincs', 'Delhi', 24.4, 40,
#         146.7, 62, 3.69, 3.19, 20.0, 1, 0, 4],
#        ['STR109', 'Electronics Zone', 'Electronincs', 'Chennai', 22.8,
#         40, 140.8, 95, 3.92, 3.15, 22.9, 1, 0, 4],
#        ['STR110', 'Apparel Zone', 'Apparel', 'Chennai', 19.2, 60, 167.6,
#         123, 3.92, 3.44, 18.3, 1, 0, 4],
#        ['STR111', 'Super Bazar', 'Super Market', 'Chennai', 17.8, 60,
#         167.6, 123, 3.92, 3.44, 18.9, 1, 0, 4],
#        ['STR112', 'Super Market', 'Super Market', 'Chennai', 16.4, 80,
#         275.8, 180, nan, 4.07, 17.4, 0, 0, 3],
#        ['STR113', 'Central Store', 'Super Market', 'Chennai', 17.3, 80,
#         275.8, 180, nan, 3.73, 17.6, 0, 0, 3],
#        ['STR114', 'Apparel Zone', 'Apparel', 'Chennai', 15.2, 80, 275.8,
#         180, nan, 3.78, 18.0, 0, 0, 3],
#        ['STR115', 'Fashion Bazar', 'Apparel', 'Chennai', 10.4, 80, 472.0,
#         205, 2.93, 5.25, 17.98, 0, 0, 3],
#        ['STR116', 'Digital Bazar', 'Electronincs', 'Chennai', 10.4, 80,
#         460.0, 215, 3.0, 5.4239999999999995, 17.82, 0, 0, 3],
#        ['STR117', 'Electronics Zone', 'Electronincs', 'Mumbai', 14.7, 80,
#         440.0, 230, 3.23, 5.345, 17.42, 0, 0, 3],
#        ['STR118', 'Apparel Zone', 'Apparel', 'Mumbai', 32.4, 40, 78.7,
#         66, 4.08, 2.2, 19.47, 1, 1, 4],
#        ['STR119', 'Super Bazar', 'Super Market', 'Mumbai', 30.4, 40,
#         75.7, 52, 4.93, 1.615, 18.52, 1, 1, 4],
#        ['STR120', 'Super Market', 'Super Market', 'Mumbai', 33.9, 40,
#         71.1, 65, 4.22, 1.835, 19.9, 1, 1, 4],
#        ['STR121', 'Central Store', 'Super Market', 'Mumbai', 21.5, 40,
#         120.1, 97, 3.7, 2.465, 20.01, 1, 0, 3],
#        ['STR122', 'Apparel Zone', 'Apparel', 'Mumbai', 15.5, 80, 318.0,
#         150, 2.76, 3.52, 16.87, 0, 0, 3],
#        ['STR123', 'Fashion Bazar', 'Apparel', 'Mumbai', 15.2, 80, 304.0,
#         150, 3.15, 3.435, 17.3, 0, 0, 3],
#        ['STR124', 'Digital Bazar', 'Electronincs', 'Mumbai', 13.3, 80,
#         350.0, 245, 3.73, 3.84, 15.41, 0, 0, 3],
#        ['STR125', 'Electronics Zone', 'Electronincs', 'Kolkata', 19.2,
#         80, 400.0, 175, 3.08, 3.845, 17.05, 0, 0, 3],
#        ['STR126', 'Apparel Zone', 'Apparel', 'Kolkata', 27.3, 40, 79.0,
#         66, 4.08, 1.935, 18.9, 1, 1, 4],
#        ['STR127', 'Super Bazar', 'Super Market', 'Kolkata', 26.0, 40,
#         120.3, 91, 4.43, 2.14, 16.7, 0, 1, 5],
#        ['STR128', 'Super Market', 'Super Market', 'Kolkata', 30.4, 40,
#         95.1, 113, 3.77, 1.5130000000000001, 16.9, 1, 1, 5],
#        ['STR129', 'Central Store', 'Super Market', 'Kolkata', 15.8, 80,
#         351.0, 264, 4.22, 3.17, 14.5, 0, 1, 5],
#        ['STR130', 'Apparel Zone', 'Apparel', 'Kolkata', 19.7, 60, 145.0,
#         175, 3.62, 2.77, 15.5, 0, 1, 5],
#        ['STR131', 'Fashion Bazar', 'Apparel', 'Kolkata', 15.0, 80, 301.0,
#         335, 3.54, 3.57, 14.6, 0, 1, 5],
#        ['STR132', 'Digital Bazar', 'Electronincs', 'Kolkata', 21.4, 40,
#         121.0, 109, 4.11, 2.78, 18.6, 1, 1, 4]], dtype=object)

# %%
y= dataset.iloc[:,3].values

# %%
print(y)
# Out:
# ['Delhi' 'Delhi' 'Delhi' 'Delhi' 'Delhi' 'Delhi' 'Delhi' 'Delhi' 'Chennai'
#  'Chennai' 'Chennai' 'Chennai' 'Chennai' 'Chennai' 'Chennai' 'Chennai'
#  'Mumbai' 'Mumbai' 'Mumbai' 'Mumbai' 'Mumbai' 'Mumbai' 'Mumbai' 'Mumbai'
#  'Kolkata' 'Kolkata' 'Kolkata' 'Kolkata' 'Kolkata' 'Kolkata' 'Kolkata'
#  'Kolkata']

# %%
dataset['Location'].unique()
# Out:
# array(['Delhi', 'Chennai', 'Mumbai', 'Kolkata'], dtype=object)

# %%
Location_order = ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
#import Libraries
from sklearn.preprocessing import OrdinalEncoder

# %%
encode_data = OrdinalEncoder(categories = [Location_order])

# %%
encode_data.fit(dataset[['Location']])
# Out:
# OrdinalEncoder(categories=[['Delhi', 'Mumbai', 'Chennai', 'Kolkata']])

# %%
final_encode = pd.DataFrame(encode_data.transform(dataset[['Location']]))

# %%
dataset['Location'] = final_encode

# %%
dataset
# Out:
#    StoreCode         StoreName     StoreType  Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs       0.0           21.0
# 1     STR102      Apparel Zone       Apparel       0.0           21.0
# 2     STR103       Super Bazar  Super Market       0.0           22.8
# 3     STR104      Super Market  Super Market       0.0           21.4
# 4     STR105     Central Store  Super Market       0.0           18.7
# 5     STR106      Apparel Zone       Apparel       0.0           18.1
# 6     STR107     Fashion Bazar       Apparel       0.0           14.3
# 7     STR108     Digital Bazar  Electronincs       0.0           24.4
# 8     STR109  Electronics Zone  Electronincs       2.0           22.8
# 9     STR110      Apparel Zone       Apparel       2.0           19.2
# 10    STR111       Super Bazar  Super Market       2.0           17.8
# 11    STR112      Super Market  Super Market       2.0           16.4
# 12    STR113     Central Store  Super Market       2.0           17.3
# 13    STR114      Apparel Zone       Apparel       2.0           15.2
# 14    STR115     Fashion Bazar       Apparel       2.0           10.4
# 15    STR116     Digital Bazar  Electronincs       2.0           10.4
# 16    STR117  Electronics Zone  Electronincs       1.0           14.7
# 17    STR118      Apparel Zone       Apparel       1.0           32.4
# 18    STR119       Super Bazar  Super Market       1.0           30.4
# 19    STR120      Super Market  Super Market       1.0           33.9
# 20    STR121     Central Store  Super Market       1.0           21.5
# 21    STR122      Apparel Zone       Apparel       1.0           15.5
# 22    STR123     Fashion Bazar       Apparel       1.0           15.2
# 23    STR124     Digital Bazar  Electronincs       1.0           13.3
# 24    STR125  Electronics Zone  Electronincs       3.0           19.2
# 25    STR126      Apparel Zone       Apparel       3.0           27.3
# 26    STR127       Super Bazar  Super Market       3.0           26.0
# 27    STR128      Super Market  Super Market       3.0           30.4
# 28    STR129     Central Store  Super Market       3.0           15.8
# 29    STR130      Apparel Zone       Apparel       3.0           19.7
# 30    STR131     Fashion Bazar       Apparel       3.0           15.0
# 31    STR132     Digital Bazar  Electronincs       3.0           21.4
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0          60       160.0              110            3.90       2.620
# 1          60       160.0              110            3.90       2.875
# 2          40       108.0               93            3.85       2.320
# 3          60       258.0              110            3.08       3.215
# 4          80       360.0              175            3.15       3.440
# 5          60       225.0              105            2.76       3.460
# 6          80       360.0              245            3.21       3.570
# 7          40       146.7               62            3.69       3.190
# 8          40       140.8               95            3.92       3.150
# 9          60       167.6              123            3.92       3.440
# 10         60       167.6              123            3.92       3.440
# 11         80       275.8              180             NaN       4.070
# 12         80       275.8              180             NaN       3.730
# 13         80       275.8              180             NaN       3.780
# 14         80       472.0              205            2.93       5.250
# 15         80       460.0              215            3.00       5.424
# 16         80       440.0              230            3.23       5.345
# 17         40        78.7               66            4.08       2.200
# 18         40        75.7               52            4.93       1.615
# 19         40        71.1               65            4.22       1.835
# 20         40       120.1               97            3.70       2.465
# 21         80       318.0              150            2.76       3.520
# 22         80       304.0              150            3.15       3.435
# 23         80       350.0              245            3.73       3.840
# 24         80       400.0              175            3.08       3.845
# 25         40        79.0               66            4.08       1.935
# 26         40       120.3               91            4.43       2.140
# 27         40        95.1              113            3.77       1.513
# 28         80       351.0              264            4.22       3.170
# 29         60       145.0              175            3.62       2.770
# 30         80       301.0              335            3.54       3.570
# 31         40       121.0              109            4.11       2.780
#
#     ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0           16.46         0               1       4             4
# 1           17.02         0               1       4             4
# 2           18.61         1               1       4             1
# 3           19.44         1               0       3             1
# 4           17.02         0               0       3             2
# 5           20.22         1               0       3             1
# 6           15.84         0               0       3             4
# 7           20.00         1               0       4             2
# 8           22.90         1               0       4             2
# 9           18.30         1               0       4             4
# 10          18.90         1               0       4             4
# 11          17.40         0               0       3             3
# 12          17.60         0               0       3             3
# 13          18.00         0               0       3             3
# 14          17.98         0               0       3             4
# 15          17.82         0               0       3             4
# 16          17.42         0               0       3             4
# 17          19.47         1               1       4             1
# 18          18.52         1               1       4             2
# 19          19.90         1               1       4             1
# 20          20.01         1               0       3             1
# 21          16.87         0               0       3             2
# 22          17.30         0               0       3             2
# 23          15.41         0               0       3             4
# 24          17.05         0               0       3             2
# 25          18.90         1               1       4             1
# 26          16.70         0               1       5             2
# 27          16.90         1               1       5             2
# 28          14.50         0               1       5             4
# 29          15.50         0               1       5             4
# 30          14.60         0               1       5             4
# 31          18.60         1               1       4             2

# %% [markdown]
# # LabelEncoder

# %%
#Libraries
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
dataset['StoreType'] = le.fit_transform(dataset['StoreType'])

# %%
dataset.head()
# Out:
#   StoreCode         StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0    STR101  Electronics Zone          1       0.0           21.0         60
# 1    STR102      Apparel Zone          0       0.0           21.0         60
# 2    STR103       Super Bazar          2       0.0           22.8         40
# 3    STR104      Super Market          2       0.0           21.4         60
# 4    STR105     Central Store          2       0.0           18.7         80
#
#    TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0       160.0              110            3.90       2.620          16.46
# 1       160.0              110            3.90       2.875          17.02
# 2       108.0               93            3.85       2.320          18.61
# 3       258.0              110            3.08       3.215          19.44
# 4       360.0              175            3.15       3.440          17.02
#
#    OwnStore  OnlinePresence  Tenure  StoreSegment
# 0         0               1       4             4
# 1         0               1       4             4
# 2         1               1       4             1
# 3         1               0       3             1
# 4         0               0       3             2

# %%
dataset.isnull()
# Out:
#     StoreCode  StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0       False      False      False     False          False      False
# 1       False      False      False     False          False      False
# 2       False      False      False     False          False      False
# 3       False      False      False     False          False      False
# 4       False      False      False     False          False      False
# 5       False      False      False     False          False      False
# 6       False      False      False     False          False      False
# 7       False      False      False     False          False      False
# 8       False      False      False     False          False      False
# 9       False      False      False     False          False      False
# 10      False      False      False     False          False      False
# 11      False      False      False     False          False      False
# 12      False      False      False     False          False      False
# 13      False      False      False     False          False      False
# 14      False      False      False     False          False      False
# 15      False      False      False     False          False      False
# 16      False      False      False     False          False      False
# 17      False      False      False     False          False      False
# 18      False      False      False     False          False      False
# 19      False      False      False     False          False      False
# 20      False      False      False     False          False      False
# 21      False      False      False     False          False      False
# 22      False      False      False     False          False      False
# 23      False      False      False     False          False      False
# 24      False      False      False     False          False      False
# 25      False      False      False     False          False      False
# 26      False      False      False     False          False      False
# 27      False      False      False     False          False      False
# 28      False      False      False     False          False      False
# 29      False      False      False     False          False      False
# 30      False      False      False     False          False      False
# 31      False      False      False     False          False      False
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        False            False           False       False          False
# 1        False            False           False       False          False
# 2        False            False           False       False          False
# 3        False            False           False       False          False
# 4        False            False           False       False          False
# 5        False            False           False       False          False
# 6        False            False           False       False          False
# 7        False            False           False       False          False
# 8        False            False           False       False          False
# 9        False            False           False       False          False
# 10       False            False           False       False          False
# 11       False            False            True       False          False
# 12       False            False            True       False          False
# 13       False            False            True       False          False
# 14       False            False           False       False          False
# 15       False            False           False       False          False
# 16       False            False           False       False          False
# 17       False            False           False       False          False
# 18       False            False           False       False          False
# 19       False            False           False       False          False
# 20       False            False           False       False          False
# 21       False            False           False       False          False
# 22       False            False           False       False          False
# 23       False            False           False       False          False
# 24       False            False           False       False          False
# 25       False            False           False       False          False
# 26       False            False           False       False          False
# 27       False            False           False       False          False
# 28       False            False           False       False          False
# 29       False            False           False       False          False
# 30       False            False           False       False          False
# 31       False            False           False       False          False
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 0      False           False   False         False
# 1      False           False   False         False
# 2      False           False   False         False
# 3      False           False   False         False
# 4      False           False   False         False
# 5      False           False   False         False
# 6      False           False   False         False
# 7      False           False   False         False
# 8      False           False   False         False
# 9      False           False   False         False
# 10     False           False   False         False
# 11     False           False   False         False
# 12     False           False   False         False
# 13     False           False   False         False
# 14     False           False   False         False
# 15     False           False   False         False
# 16     False           False   False         False
# 17     False           False   False         False
# 18     False           False   False         False
# 19     False           False   False         False
# 20     False           False   False         False
# 21     False           False   False         False
# 22     False           False   False         False
# 23     False           False   False         False
# 24     False           False   False         False
# 25     False           False   False         False
# 26     False           False   False         False
# 27     False           False   False         False
# 28     False           False   False         False
# 29     False           False   False         False
# 30     False           False   False         False
# 31     False           False   False         False

# %%
dataset.isnull().sum()
# Out:
# StoreCode          0
# StoreName          0
# StoreType          0
# Location           0
# OperatingCost      0
# Staff_Cnt          0
# TotalSales         0
# Total_Customers    0
# AcqCostPercust     3
# BasketSize         0
# ProfitPercust      0
# OwnStore           0
# OnlinePresence     0
# Tenure             0
# StoreSegment       0
# dtype: int64

# %%
dataset.dropna()  #Drop Null Attribute
# Out:
#    StoreCode         StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0     STR101  Electronics Zone          1       0.0           21.0         60
# 1     STR102      Apparel Zone          0       0.0           21.0         60
# 2     STR103       Super Bazar          2       0.0           22.8         40
# 3     STR104      Super Market          2       0.0           21.4         60
# 4     STR105     Central Store          2       0.0           18.7         80
# 5     STR106      Apparel Zone          0       0.0           18.1         60
# 6     STR107     Fashion Bazar          0       0.0           14.3         80
# 7     STR108     Digital Bazar          1       0.0           24.4         40
# 8     STR109  Electronics Zone          1       2.0           22.8         40
# 9     STR110      Apparel Zone          0       2.0           19.2         60
# 10    STR111       Super Bazar          2       2.0           17.8         60
# 14    STR115     Fashion Bazar          0       2.0           10.4         80
# 15    STR116     Digital Bazar          1       2.0           10.4         80
# 16    STR117  Electronics Zone          1       1.0           14.7         80
# 17    STR118      Apparel Zone          0       1.0           32.4         40
# 18    STR119       Super Bazar          2       1.0           30.4         40
# 19    STR120      Super Market          2       1.0           33.9         40
# 20    STR121     Central Store          2       1.0           21.5         40
# 21    STR122      Apparel Zone          0       1.0           15.5         80
# 22    STR123     Fashion Bazar          0       1.0           15.2         80
# 23    STR124     Digital Bazar          1       1.0           13.3         80
# 24    STR125  Electronics Zone          1       3.0           19.2         80
# 25    STR126      Apparel Zone          0       3.0           27.3         40
# 26    STR127       Super Bazar          2       3.0           26.0         40
# 27    STR128      Super Market          2       3.0           30.4         40
# 28    STR129     Central Store          2       3.0           15.8         80
# 29    STR130      Apparel Zone          0       3.0           19.7         60
# 30    STR131     Fashion Bazar          0       3.0           15.0         80
# 31    STR132     Digital Bazar          1       3.0           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 7        146.7               62            3.69       3.190          20.00
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 23       350.0              245            3.73       3.840          15.41
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 28       351.0              264            4.22       3.170          14.50
# 29       145.0              175            3.62       2.770          15.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          0               1       4             4
# 1          0               1       4             4
# 2          1               1       4             1
# 3          1               0       3             1
# 4          0               0       3             2
# 5          1               0       3             1
# 6          0               0       3             4
# 7          1               0       4             2
# 8          1               0       4             2
# 9          1               0       4             4
# 10         1               0       4             4
# 14         0               0       3             4
# 15         0               0       3             4
# 16         0               0       3             4
# 17         1               1       4             1
# 18         1               1       4             2
# 19         1               1       4             1
# 20         1               0       3             1
# 21         0               0       3             2
# 22         0               0       3             2
# 23         0               0       3             4
# 24         0               0       3             2
# 25         1               1       4             1
# 26         0               1       5             2
# 27         1               1       5             2
# 28         0               1       5             4
# 29         0               1       5             4
# 30         0               1       5             4
# 31         1               1       4             2

# %%
#Filling with 0
dataset.fillna(0)
# Out:
#    StoreCode         StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0     STR101  Electronics Zone          1       0.0           21.0         60
# 1     STR102      Apparel Zone          0       0.0           21.0         60
# 2     STR103       Super Bazar          2       0.0           22.8         40
# 3     STR104      Super Market          2       0.0           21.4         60
# 4     STR105     Central Store          2       0.0           18.7         80
# 5     STR106      Apparel Zone          0       0.0           18.1         60
# 6     STR107     Fashion Bazar          0       0.0           14.3         80
# 7     STR108     Digital Bazar          1       0.0           24.4         40
# 8     STR109  Electronics Zone          1       2.0           22.8         40
# 9     STR110      Apparel Zone          0       2.0           19.2         60
# 10    STR111       Super Bazar          2       2.0           17.8         60
# 11    STR112      Super Market          2       2.0           16.4         80
# 12    STR113     Central Store          2       2.0           17.3         80
# 13    STR114      Apparel Zone          0       2.0           15.2         80
# 14    STR115     Fashion Bazar          0       2.0           10.4         80
# 15    STR116     Digital Bazar          1       2.0           10.4         80
# 16    STR117  Electronics Zone          1       1.0           14.7         80
# 17    STR118      Apparel Zone          0       1.0           32.4         40
# 18    STR119       Super Bazar          2       1.0           30.4         40
# 19    STR120      Super Market          2       1.0           33.9         40
# 20    STR121     Central Store          2       1.0           21.5         40
# 21    STR122      Apparel Zone          0       1.0           15.5         80
# 22    STR123     Fashion Bazar          0       1.0           15.2         80
# 23    STR124     Digital Bazar          1       1.0           13.3         80
# 24    STR125  Electronics Zone          1       3.0           19.2         80
# 25    STR126      Apparel Zone          0       3.0           27.3         40
# 26    STR127       Super Bazar          2       3.0           26.0         40
# 27    STR128      Super Market          2       3.0           30.4         40
# 28    STR129     Central Store          2       3.0           15.8         80
# 29    STR130      Apparel Zone          0       3.0           19.7         60
# 30    STR131     Fashion Bazar          0       3.0           15.0         80
# 31    STR132     Digital Bazar          1       3.0           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 7        146.7               62            3.69       3.190          20.00
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 11       275.8              180            0.00       4.070          17.40
# 12       275.8              180            0.00       3.730          17.60
# 13       275.8              180            0.00       3.780          18.00
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 23       350.0              245            3.73       3.840          15.41
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 28       351.0              264            4.22       3.170          14.50
# 29       145.0              175            3.62       2.770          15.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          0               1       4             4
# 1          0               1       4             4
# 2          1               1       4             1
# 3          1               0       3             1
# 4          0               0       3             2
# 5          1               0       3             1
# 6          0               0       3             4
# 7          1               0       4             2
# 8          1               0       4             2
# 9          1               0       4             4
# 10         1               0       4             4
# 11         0               0       3             3
# 12         0               0       3             3
# 13         0               0       3             3
# 14         0               0       3             4
# 15         0               0       3             4
# 16         0               0       3             4
# 17         1               1       4             1
# 18         1               1       4             2
# 19         1               1       4             1
# 20         1               0       3             1
# 21         0               0       3             2
# 22         0               0       3             2
# 23         0               0       3             4
# 24         0               0       3             2
# 25         1               1       4             1
# 26         0               1       5             2
# 27         1               1       5             2
# 28         0               1       5             4
# 29         0               1       5             4
# 30         0               1       5             4
# 31         1               1       4             2

# %%
dataset['AcqCostPercust'].mean()
# Out:
# 3.651034482758621

# %%
dataset.fillna({'AcqCostPercust' : 3.65})
# Out:
#    StoreCode         StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0     STR101  Electronics Zone          1       0.0           21.0         60
# 1     STR102      Apparel Zone          0       0.0           21.0         60
# 2     STR103       Super Bazar          2       0.0           22.8         40
# 3     STR104      Super Market          2       0.0           21.4         60
# 4     STR105     Central Store          2       0.0           18.7         80
# 5     STR106      Apparel Zone          0       0.0           18.1         60
# 6     STR107     Fashion Bazar          0       0.0           14.3         80
# 7     STR108     Digital Bazar          1       0.0           24.4         40
# 8     STR109  Electronics Zone          1       2.0           22.8         40
# 9     STR110      Apparel Zone          0       2.0           19.2         60
# 10    STR111       Super Bazar          2       2.0           17.8         60
# 11    STR112      Super Market          2       2.0           16.4         80
# 12    STR113     Central Store          2       2.0           17.3         80
# 13    STR114      Apparel Zone          0       2.0           15.2         80
# 14    STR115     Fashion Bazar          0       2.0           10.4         80
# 15    STR116     Digital Bazar          1       2.0           10.4         80
# 16    STR117  Electronics Zone          1       1.0           14.7         80
# 17    STR118      Apparel Zone          0       1.0           32.4         40
# 18    STR119       Super Bazar          2       1.0           30.4         40
# 19    STR120      Super Market          2       1.0           33.9         40
# 20    STR121     Central Store          2       1.0           21.5         40
# 21    STR122      Apparel Zone          0       1.0           15.5         80
# 22    STR123     Fashion Bazar          0       1.0           15.2         80
# 23    STR124     Digital Bazar          1       1.0           13.3         80
# 24    STR125  Electronics Zone          1       3.0           19.2         80
# 25    STR126      Apparel Zone          0       3.0           27.3         40
# 26    STR127       Super Bazar          2       3.0           26.0         40
# 27    STR128      Super Market          2       3.0           30.4         40
# 28    STR129     Central Store          2       3.0           15.8         80
# 29    STR130      Apparel Zone          0       3.0           19.7         60
# 30    STR131     Fashion Bazar          0       3.0           15.0         80
# 31    STR132     Digital Bazar          1       3.0           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 0        160.0              110            3.90       2.620          16.46
# 1        160.0              110            3.90       2.875          17.02
# 2        108.0               93            3.85       2.320          18.61
# 3        258.0              110            3.08       3.215          19.44
# 4        360.0              175            3.15       3.440          17.02
# 5        225.0              105            2.76       3.460          20.22
# 6        360.0              245            3.21       3.570          15.84
# 7        146.7               62            3.69       3.190          20.00
# 8        140.8               95            3.92       3.150          22.90
# 9        167.6              123            3.92       3.440          18.30
# 10       167.6              123            3.92       3.440          18.90
# 11       275.8              180            3.65       4.070          17.40
# 12       275.8              180            3.65       3.730          17.60
# 13       275.8              180            3.65       3.780          18.00
# 14       472.0              205            2.93       5.250          17.98
# 15       460.0              215            3.00       5.424          17.82
# 16       440.0              230            3.23       5.345          17.42
# 17        78.7               66            4.08       2.200          19.47
# 18        75.7               52            4.93       1.615          18.52
# 19        71.1               65            4.22       1.835          19.90
# 20       120.1               97            3.70       2.465          20.01
# 21       318.0              150            2.76       3.520          16.87
# 22       304.0              150            3.15       3.435          17.30
# 23       350.0              245            3.73       3.840          15.41
# 24       400.0              175            3.08       3.845          17.05
# 25        79.0               66            4.08       1.935          18.90
# 26       120.3               91            4.43       2.140          16.70
# 27        95.1              113            3.77       1.513          16.90
# 28       351.0              264            4.22       3.170          14.50
# 29       145.0              175            3.62       2.770          15.50
# 30       301.0              335            3.54       3.570          14.60
# 31       121.0              109            4.11       2.780          18.60
#
#     OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          0               1       4             4
# 1          0               1       4             4
# 2          1               1       4             1
# 3          1               0       3             1
# 4          0               0       3             2
# 5          1               0       3             1
# 6          0               0       3             4
# 7          1               0       4             2
# 8          1               0       4             2
# 9          1               0       4             4
# 10         1               0       4             4
# 11         0               0       3             3
# 12         0               0       3             3
# 13         0               0       3             3
# 14         0               0       3             4
# 15         0               0       3             4
# 16         0               0       3             4
# 17         1               1       4             1
# 18         1               1       4             2
# 19         1               1       4             1
# 20         1               0       3             1
# 21         0               0       3             2
# 22         0               0       3             2
# 23         0               0       3             4
# 24         0               0       3             2
# 25         1               1       4             1
# 26         0               1       5             2
# 27         1               1       5             2
# 28         0               1       5             4
# 29         0               1       5             4
# 30         0               1       5             4
# 31         1               1       4             2

# %% [markdown]
# # Splitting the Dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state=0)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [['STR127' 'Super Bazar' 'Super Market' 'Kolkata' 26.0 40 120.3 91 4.43
#   2.14 16.7 0 1 5]
#  ['STR121' 'Central Store' 'Super Market' 'Mumbai' 21.5 40 120.1 97 3.7
#   2.465 20.01 1 0 3]
#  ['STR114' 'Apparel Zone' 'Apparel' 'Chennai' 15.2 80 275.8 180 nan 3.78
#   18.0 0 0 3]
#  ['STR125' 'Electronics Zone' 'Electronincs' 'Kolkata' 19.2 80 400.0 175
#   3.08 3.845 17.05 0 0 3]
#  ['STR106' 'Apparel Zone' 'Apparel' 'Delhi' 18.1 60 225.0 105 2.76 3.46
#   20.22 1 0 3]
#  ['STR118' 'Apparel Zone' 'Apparel' 'Mumbai' 32.4 40 78.7 66 4.08 2.2
#   19.47 1 1 4]
#  ['STR109' 'Electronics Zone' 'Electronincs' 'Chennai' 22.8 40 140.8 95
#   3.92 3.15 22.9 1 0 4]
#  ['STR131' 'Fashion Bazar' 'Apparel' 'Kolkata' 15.0 80 301.0 335 3.54
#   3.57 14.6 0 1 5]
#  ['STR126' 'Apparel Zone' 'Apparel' 'Kolkata' 27.3 40 79.0 66 4.08 1.935
#   18.9 1 1 4]
#  ['STR124' 'Digital Bazar' 'Electronincs' 'Mumbai' 13.3 80 350.0 245 3.73
#   3.84 15.41 0 0 3]
#  ['STR102' 'Apparel Zone' 'Apparel' 'Delhi' 21.0 60 160.0 110 3.9 2.875
#   17.02 0 1 4]
#  ['STR132' 'Digital Bazar' 'Electronincs' 'Kolkata' 21.4 40 121.0 109
#   4.11 2.78 18.6 1 1 4]
#  ['STR107' 'Fashion Bazar' 'Apparel' 'Delhi' 14.3 80 360.0 245 3.21 3.57
#   15.84 0 0 3]
#  ['STR105' 'Central Store' 'Super Market' 'Delhi' 18.7 80 360.0 175 3.15
#   3.44 17.02 0 0 3]
#  ['STR119' 'Super Bazar' 'Super Market' 'Mumbai' 30.4 40 75.7 52 4.93
#   1.615 18.52 1 1 4]
#  ['STR130' 'Apparel Zone' 'Apparel' 'Kolkata' 19.7 60 145.0 175 3.62 2.77
#   15.5 0 1 5]
#  ['STR120' 'Super Market' 'Super Market' 'Mumbai' 33.9 40 71.1 65 4.22
#   1.835 19.9 1 1 4]
#  ['STR110' 'Apparel Zone' 'Apparel' 'Chennai' 19.2 60 167.6 123 3.92 3.44
#   18.3 1 0 4]
#  ['STR108' 'Digital Bazar' 'Electronincs' 'Delhi' 24.4 40 146.7 62 3.69
#   3.19 20.0 1 0 4]
#  ['STR128' 'Super Market' 'Super Market' 'Kolkata' 30.4 40 95.1 113 3.77
#   1.5130000000000001 16.9 1 1 5]
#  ['STR104' 'Super Market' 'Super Market' 'Delhi' 21.4 60 258.0 110 3.08
#   3.215 19.44 1 0 3]
#  ['STR101' 'Electronics Zone' 'Electronincs' 'Delhi' 21.0 60 160.0 110
#   3.9 2.62 16.46 0 1 4]
#  ['STR122' 'Apparel Zone' 'Apparel' 'Mumbai' 15.5 80 318.0 150 2.76 3.52
#   16.87 0 0 3]
#  ['STR116' 'Digital Bazar' 'Electronincs' 'Chennai' 10.4 80 460.0 215 3.0
#   5.4239999999999995 17.82 0 0 3]
#  ['STR113' 'Central Store' 'Super Market' 'Chennai' 17.3 80 275.8 180 nan
#   3.73 17.6 0 0 3]]
# [['STR112' 'Super Market' 'Super Market' 'Chennai' 16.4 80 275.8 180 nan
#   4.07 17.4 0 0 3]
#  ['STR123' 'Fashion Bazar' 'Apparel' 'Mumbai' 15.2 80 304.0 150 3.15
#   3.435 17.3 0 0 3]
#  ['STR111' 'Super Bazar' 'Super Market' 'Chennai' 17.8 60 167.6 123 3.92
#   3.44 18.9 1 0 4]
#  ['STR103' 'Super Bazar' 'Super Market' 'Delhi' 22.8 40 108.0 93 3.85
#   2.32 18.61 1 1 4]
#  ['STR117' 'Electronics Zone' 'Electronincs' 'Mumbai' 14.7 80 440.0 230
#   3.23 5.345 17.42 0 0 3]
#  ['STR115' 'Fashion Bazar' 'Apparel' 'Chennai' 10.4 80 472.0 205 2.93
#   5.25 17.98 0 0 3]
#  ['STR129' 'Central Store' 'Super Market' 'Kolkata' 15.8 80 351.0 264
#   4.22 3.17 14.5 0 1 5]]
# ['Kolkata' 'Mumbai' 'Chennai' 'Kolkata' 'Delhi' 'Mumbai' 'Chennai'
#  'Kolkata' 'Kolkata' 'Mumbai' 'Delhi' 'Kolkata' 'Delhi' 'Delhi' 'Mumbai'
#  'Kolkata' 'Mumbai' 'Chennai' 'Delhi' 'Kolkata' 'Delhi' 'Delhi' 'Mumbai'
#  'Chennai' 'Chennai']
# ['Chennai' 'Mumbai' 'Chennai' 'Delhi' 'Mumbai' 'Chennai' 'Kolkata']
